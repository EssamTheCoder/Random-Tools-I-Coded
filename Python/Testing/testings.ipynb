# %% [markdown]
# - V = Working Version
# - B = Beta Version
# - A = Alpha Version
#
#
# Version Number (changed when major updates/revamps happen).Minor Number(cahnged when changes to the major version happen)
#
# This is the version identification system for all the programs here
# DO NOT DELETE

# %%
length = input('len: ')
if length.isdecimal() == True:
    print('int')
elif length.lower() == 'random':
    print('random')
else:
    print('invalid')
# Out:
# invalid

# %%
from numpy import arange
ranged = arange(50,200)
print(ranged[1])
# Out:
# 51

# %%
#Tests if you can send inputs through a function directly: Yes, yes you can.
def returnsWith1(inp: str) -> str:
    return f"{inp}1"
print(returnsWith1(input("Testing: ")))
# Out:
# fah1
