# %% [markdown]
# - V = Working Version
# - B = Beta Version
# - A = Alpha Version
#
#
# Version Number (changed when major updates/revamps happen).Minor Number(changed when changes to the major version happen)
#
# This is the version identification system for all the programs here
# DO NOT DELETE

# %%
method = input("text goes here: ")
method.replace(' ','').lower()
# Out:
# 'rerrrrrrrr='

# %%
def test(x:int, y:float):
    return x+1, y-1

print(test(1,31))
print( type(test(1,31)) )
# Out:
# (2, 30)
# <class 'tuple'>

# %%
{ #Expected return: set, dict, tuple, list
    "a": [1,2,4,5],
    "b": (0,1,2),
    "c": {"a": 1, "b": 2},
    "d": {1}
}

# %%
length = input('len: ')
if length.isdecimal() == True:
    print('int')
elif length.lower() == 'random':
    print('random')
else:
    print('invalid')
# Out:
# invalid

# %%
from numpy import arange
ranged = arange(50,200)
print(ranged[1])
# Out:
# 51

# %%
#Tests if you can send inputs through a function directly: Yes, yes you can.
def returnsWith1(inp: str) -> str:
    return f"{inp}1"
print(returnsWith1(input("Testing: ")))
# Out:
# fah1
